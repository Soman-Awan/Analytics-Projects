# %%
CREATED BY SOMAN SAJID -- MMA 192 | PRACTICAL MACHINE LEARNING

# %%
#IMPORTING LIBRARY

import numpy as np # Linear Algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
#LOADING DATASET FOR SUPER MARKET SALES
SS = pd.read_csv("D:/Studies -/MIMBA/1st Year/4th Module/Practical Machine Learning/TASK 01/SSales.csv")

#CHECK IF DATA IS LOADED
SS.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
#PROVIDING BASIC DESCRIPTION 
SS.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.220360e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# ...

# %%
#TO GET MORE INSIGHTS ON TYPE OF DATA, ENTRIES, COLUMNS, OBSERVATIONS
SS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
#HISTOGRAM -- TO SEE IF THE DATA IS SKEWED AND TO SEE ITS DISTRIBUTION
##HERE WE CAN SEE THAT DATA IS POSITVE SKEWED

plt.figure(figsize=(12,5))
sns.distplot(SS['gross income'], kde=False)

# %%
#ANOTHER WAY TO SEE THE DESCRIPTIVE STATS IS TO SEE THE CORRELATION MATRIX
##WE CAN SEE HERE RATING, GROSS MARGIN & GM PERCENTAGE ARE LESS CORRELATED WITH OTHER VARIABLES
corrMatrix = SS.corr()
sn.heatmap(corrMatrix, annot=False)
plt.show()

# %%
TASK 5 : DATA INDEXING

# %%
#HERE WE CAN SEE BY COLUMN NAME DATA
SS['City']
# Out:
# 0         Yangon
# 1      Naypyitaw
# 2         Yangon
# 3         Yangon
# 4         Yangon
#          ...
# 995    Naypyitaw
# 996     Mandalay
# 997       Yangon
# 998       Yangon
# 999       Yangon
# Name: City, Length: 1000, dtype: object

# %%
#HERE WE HAVE CREATED A NEW VARIABLES COG PERCENTAGE TO INCOME USING INDEXING
SS['COG Percentage to Income'] = SS['gross income'] / SS['cogs']
SS
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
#NUMPY ARRAY STYLE INDEXING -- HERE I WANT TO SEE DATA FROM 100-110 ROWS AND 3-7 COLUMNS
SS.iloc[100:111,3:7]
# Out:
#     Customer type  Gender            Product line  Unit price
# 100        Member    Male     Fashion accessories       48.71
# 101        Normal    Male     Fashion accessories       78.55
# 102        Normal  Female  Electronic accessories       23.07
# 103        Normal    Male      Food and beverages       58.26
# 104        Normal    Male       Health and beauty       30.35
# 105        Member    Male  Electronic accessories       88.67
# 106        Normal    Male     Fashion accessories       27.38
# 107        Normal    Male       Sports and travel       62.13
# 108        Normal  Female      Food and beverages       33.98
# 109        Member    Male  Electronic accessories       81.97
# 110        Member  Female       Sports and travel       16.49

# %%
#HERE I AM INTERESTED TO SEE SALES WHICH HAS QUANTITY OF MORE THAN 07 WITH RESPECT TO GENDER AND GROSS INCOME

SS.loc[SS.Quantity > 7, ['Gender', 'gross income']]
# Out:
#      Gender  gross income
# 3      Male        23.288
# 7    Female        36.780
# 13     Male        21.595
# 14   Female        35.690
# 25   Female        21.036
# ..      ...           ...
# 988    Male        41.170
# 989    Male        30.148
# 991  Female        38.300
# 993    Male         8.745
# 996  Female        48.690
#
# [296 rows x 2 columns]

# %%
#HERE I AM INTERESTED TO SEE SALES WHICH HAS QUANTITY OF MORE THAN 09 WITH RESPECT TO GENDER, GROSS INCOME, RATING

SS.loc[SS.Quantity > 9, ['Gender', 'gross income', 'Rating']]
# Out:
#      Gender  gross income  Rating
# 7    Female        36.780     8.0
# 13     Male        21.595     8.2
# 14   Female        35.690     5.7
# 49   Female        41.315     7.9
# 58   Female        36.175     5.4
# ..      ...           ...     ...
# 970  Female        42.315     9.0
# 988    Male        41.170     4.3
# 991  Female        38.300     6.0
# 993    Male         8.745     6.6
# 996  Female        48.690     4.4
#
# [119 rows x 3 columns]

# %%
#HERE I HAVE CREATED ANOTHER VARIABLE AS TOTAL INCOME IN EURO

SS['Total Income in EURO'] = (SS['Total'] * 0.9) 
SS.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
TASK 6 : DATA SLICING

# %%
#HERE I WANT TO EXTRACT ONLY THE DATA FOR CITY, CUSTOMER TYPE, GENDER, PRODUCT LINE, UNIT PRICE & QUANTITY 
##I HAVE CREATED A SEPARATE DF AS SS1
SS1 = SS.iloc[:,2:8]

SS1.head()
# Out:
#         City Customer type  Gender            Product line  Unit price  \
# 0     Yangon        Member  Female       Health and beauty       74.69
# 1  Naypyitaw        Normal  Female  Electronic accessories       15.28
# 2     Yangon        Normal    Male      Home and lifestyle       46.33
# 3     Yangon        Member    Male       Health and beauty       58.22
# 4     Yangon        Normal    Male       Sports and travel       86.31
#
#    Quantity
# 0         7
# 1         5
# 2         7
# 3         8
# 4         7

# %%
#Here I HAVE CREATED A DF AS FSS FOR THE FIRST 100 OBSERVATIONS AND FOR ALL COLUMN

FSS = SS.iloc[:100,:]
FSS.info()

#We can see now we have only 100 observations 19 columns (since I've added  Total Income in EURO & COG Percentage to Income)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Invoice ID                100 non-null    object
#  1   Branch                    100 non-null    object
#  2   City                      100 non-null    object
#  3   Customer type             100 non-null    object
#  4   Gender                    100 non-null    object
#  5   Product line              100 non-null    object
#  6   Unit price                100 non-null    float64
#  7   Quantity                  100 non-null    int64
#  8   Tax 5%                    100 non-null    float64
#  9   Total                     100 non-null    float64
#  10  Date                      100 non-null    object
#  11  Time                      100 non-null    object
#  12  Payment                   100 non-null    object
# ...

# %%
TASK 7: DATA MASKING

# %%
#Let's suppose I want to extract data when the rating is greater than 08 and analyze the values for ...
    ##...Gender, Quantity Cost of Goods Sold (COGS) & Payment
SS2 = SS.loc[SS.Rating > 8,['Gender','Quantity','Payment','cogs']]
SS2.head()
# Out:
#     Gender  Quantity      Payment    cogs
# 0   Female         7      Ewallet  522.83
# 1   Female         5         Cash   76.40
# 3     Male         8      Ewallet  465.76
# 13    Male        10      Ewallet  431.90
# 18    Male         3  Credit card  164.01

# %%
#An example for correlation matrix 
corrMatrix2 = SS2.corr()
sn.heatmap(corrMatrix2, annot=False)
plt.show()

# %%
TASK 8: Data Fancy Indexing

# %%
#Creating Dummy for Gender 
SS_Gender = pd.get_dummies(SS['Gender'])
SS_Gender.head()
SS_new = SS.join(SS_Gender)
SS_new.head()

#So our new Dataframe is SS_New
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total  ...  \
# 0       Health and beauty       74.69         7  26.1415  548.9715  ...
# 1  Electronic accessories       15.28         5   3.8200   80.2200  ...
# 2      Home and lifestyle       46.33         7  16.2155  340.5255  ...
# 3       Health and beauty       58.22         8  23.2880  489.0480  ...
# 4       Sports and travel       86.31         7  30.2085  634.3785  ...
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
#Now I am extracting a spefic number (say Invoice ID) of 101th Observation
SS_new.iloc[100, 0]
# Out:
# '163-56-7055'

# %%
#Just to show the data point we selected above 2405395.22
RD.head()

# %%
#Now say I want to see the Invoice ID from 100-103
SS_new.iloc[100:104, 0]
# Out:
# 100    163-56-7055
# 101    189-98-2939
# 102    551-21-3069
# 103    212-62-1842
# Name: Invoice ID, dtype: object

# %%
CREATED BY SOMAN SAJID -- MMA 192
